# %%
import pandas as pd

# %%
# 파일 경로를 따와서 넣을 수 있다. (변수에 넣고, encoding도 실행(만약 안되면) 그리고 pd.read_csv()로 불러온다.
# 다운로드 받고 ctrl+j눌린다음 링크 주소 복사를 볼 수 있음.
# utf-8 을 ms949로 자주 쓴다! 핫 키!

# %%
targetUrl = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002477494&fileDetailSn=1&dataNm=%ED%95%9C%EA%B5%AD%EC%A3%BC%ED%83%9D%EA%B8%88%EC%9C%B5%EA%B3%B5%EC%82%AC_%EC%A7%80%EC%97%AD%EB%B3%84%20PIR%20%EB%B0%8F%20LIR_20200501"

# %%
indata = pd.read_csv(targetUrl, encoding = "ms949")

# %%
indata.tail()
# Out:
#        연도  월  전국(PIR)  서울(PIR)  부산(PIR)  대구(PIR)  인천(PIR)  광주(PIR)  대전(PIR)  \
# 190  2020  1     4.47     5.44     4.84     5.16     4.39     4.76     4.52
# 191  2020  2     4.45     5.02     5.04     4.92     4.49     4.52     4.36
# 192  2020  3     4.76     5.12     5.22     5.20     4.76     5.04     4.74
# 193  2020  4     4.83     4.95     5.67     5.91     4.78     5.41     5.40
# 194  2020  5     4.56     4.88     7.01     5.44     4.56     3.16     4.72
#
#      울산(PIR)  ...  세종(LIR)  경기(LIR)  강원(LIR)  충북(LIR)  충남(LIR)  전북(LIR)  \
# 190     4.11  ...     2.63     2.39     1.90     1.76     1.87     1.94
# 191     3.90  ...     2.69     2.34     1.96     1.87     1.89     1.83
# 192     4.11  ...     2.22     2.56     2.13     1.98     2.03     1.97
# 193     4.44  ...     1.73     2.54     2.13     2.09     2.14     2.11
# 194     5.77  ...     0.00     2.23     2.44     1.08     1.65     1.04
#
#      전남(LIR)  경북(LIR)  경남(LIR)  제주(LIR)
# ...

# %%
targetUrl2 = "https://www.data.go.kr/cmm/cmm/fileDownload.do?atchFileId=FILE_000000002336443&fileDetailSn=1&dataNm=%ED%86%B5%EA%B3%84%EC%B2%AD_%EB%82%98%EB%9D%BC%ED%86%B5%EA%B3%84_%EC%9A%B0%ED%8E%B8%EB%B2%88%ED%98%B8_20211110"

indata2 = pd.read_csv(targetUrl2, encoding = "ms949")

# %%
indata2
# Out:
#          우편번호  우편번호순서    도이름 시군구이름 읍면동이름         리건물이름              동호  \
# 0      137926      11  서울특별시   서초구  서초1동           NaN  1641-1~1641-13
# 1      137927      11  서울특별시   서초구  서초3동           NaN            1451
# 2      137929      12  서울특별시   서초구  서초4동  서초교대e편한세상아파트      (101~106동)
# 3      137930       2  서울특별시   서초구  반포1동       반포자이아파트      (101~144동)
# 4      137931       2  서울특별시   서초구  반포1동       삼호가든아파트      (501~503동)
# ...       ...     ...    ...   ...   ...           ...             ...
# 52538  799821      31   경상북도   울릉군    북면            나리             NaN
# 52539  799822      21   경상북도   울릉군    북면          천부4리             NaN
# 52540  799822      11   경상북도   울릉군    북면          천부3리             NaN
# 52541  799822       1   경상북도   울릉군    북면          나리2리             NaN
# 52542  799823       1   경상북도   울릉군    북면           현포리             NaN
#
#                                          전체주소
# 0               서울특별시 서초구 서초1동 1641-1~1641-13
# ...

# %% [markdown]
# # 4.json 데이터 불러오기

# %%
url = "https://kosis.kr/openapi/statisticsData.do?method=getList&apiKey=MjQyODJiOGM0YzBmODQ1YTBkZDE4NzZkYmRjNmIzM2I=&format=json&jsonVD=Y&userStatsId=ddingddol/101/DT_1B040A3/2/1/20220405102832&prdSe=M&newEstPrdCnt=1"

# %%
try:
    json = pd.read_json(url)
except Exception as e:
    print(e)
json
# Out:
#                TBL_NM  PRD_DE      TBL_ID ITM_NM        ITM_NM_ENG ITM_ID  \
# 0   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수   Koreans (Total)    T20
# 1   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 2   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 3   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수   Koreans (Total)    T20
# 4   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 5   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 6   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수   Koreans (Total)    T20
# 7   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 8   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  여자인구수  Koreans (Female)    T22
# 9   행정구역(시군구)별 성별 인구수  202203  DT_1B040A3   총인구수   Koreans (Total)    T20
# 10  행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  남자인구수    Koreans (Male)    T21
# 11  행정구역(시군구)별 성별 인구수  202203  DT_1B040A3  여자인구수  Koreans (Female)    T22
# ...

# %%
# XML??  Extensible Markup Language

# %%
# 개인 인증키
7MWa6h%2FzhFG0Gg3LEIzEQNscntTjt%2FbKeTyC1gcA4i9bYx7nFj336WmW0zXzUDK%2FNPQzC7iOla5fq%2BeUhFNEXw%3D%3D

# %%
url2 = "http://openapi.molit.go.kr:8081/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTrade?LAWD_CD=11110&DEAL_YMD=201512&serviceKey=AT33s775KYpJOkUBJu0dxkJuUeIfDIOJRzAH084EQS3JN%2BzFjErLHuk%2FGZa9L4gBTSGCzeA69tI9PwLp7B37IQ%3D%3D"

# %%
import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd

# %%
resp = requests.get(url2)

# %%
resp.encoding = 'utf-8'

# %%
resp.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    82,500</거래금액><거래유형> </거래유형><건축년도>2008</건축년도><년>2015</년><법정동> 사직동</법정동><아파트>광화문스페이스본(101동~105동)</아파트><월>12</월><일>10</일><전용면적>94.51</전용면적><중개사소재지> </중개사소재지><지번>9</지번><지역코드>11110</지역코드><층>11</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    60,000</거래금액><거래유형> </거래유형><건축년도>1981</건축년도><년>2015</년><법정동> 당주동</법정동><아파트>롯데미도파광화문빌딩</아파트><월>12</월><일>22</일><전용면적>149.95</전용면적><중개사소재지> </중개사소재지><지번>145</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   130,000</거래금액><거래유형> </거래유형><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>킹스매너</아파트><월>12</월><일>8</일><전용면적>194.43</전용면적><중개사소재지> </중개사소재지><지번>110-15</지번><지역코드>11110</지역코드><층>6</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   105,000</거래금액><거래유형> </거래유형><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>경희궁의아침2단지</아파트><월>12
# ...

# %%
xmlobj = bs4.BeautifulSoup(resp.text,"lxml-xml")

# %%
xmlobj
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# ...

# %%
itemsTag = xmlobj.find(name="items")

# %%
itemsTag
# Out:
# <items><item><거래금액>    82,500</거래금액><거래유형> </거래유형><건축년도>2008</건축년도><년>2015</년><법정동> 사직동</법정동><아파트>광화문스페이스본(101동~105동)</아파트><월>12</월><일>10</일><전용면적>94.51</전용면적><중개사소재지> </중개사소재지><지번>9</지번><지역코드>11110</지역코드><층>11</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    60,000</거래금액><거래유형> </거래유형><건축년도>1981</건축년도><년>2015</년><법정동> 당주동</법정동><아파트>롯데미도파광화문빌딩</아파트><월>12</월><일>22</일><전용면적>149.95</전용면적><중개사소재지> </중개사소재지><지번>145</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   130,000</거래금액><거래유형> </거래유형><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>킹스매너</아파트><월>12</월><일>8</일><전용면적>194.43</전용면적><중개사소재지> </중개사소재지><지번>110-15</지번><지역코드>11110</지역코드><층>6</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   105,000</거래금액><거래유형> </거래유형><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>경희궁의아침2단지</아파트><월>12</월><일>14</일><전용면적>124.17</전용면적><중개사소재지> </중개사소재지><지번>71</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>   120,000</거래
# ...

# %%
itemTag = itemsTag.findAll(name="item")

# %%
itemTag
# Out:
# [<item><거래금액>    82,500</거래금액><거래유형> </거래유형><건축년도>2008</건축년도><년>2015</년><법정동> 사직동</법정동><아파트>광화문스페이스본(101동~105동)</아파트><월>12</월><일>10</일><전용면적>94.51</전용면적><중개사소재지> </중개사소재지><지번>9</지번><지역코드>11110</지역코드><층>11</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>    60,000</거래금액><거래유형> </거래유형><건축년도>1981</건축년도><년>2015</년><법정동> 당주동</법정동><아파트>롯데미도파광화문빌딩</아파트><월>12</월><일>22</일><전용면적>149.95</전용면적><중개사소재지> </중개사소재지><지번>145</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>   130,000</거래금액><거래유형> </거래유형><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>킹스매너</아파트><월>12</월><일>8</일><전용면적>194.43</전용면적><중개사소재지> </중개사소재지><지번>110-15</지번><지역코드>11110</지역코드><층>6</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
#  <item><거래금액>   105,000</거래금액><거래유형> </거래유형><건축년도>2004</건축년도><년>2015</년><법정동> 내수동</법정동><아파트>경희궁의아침2단지</아파트><월>12</월><일>14</일><전용면적>124.17</전용면적><중개사소재지> </중개사소재지><지번>71</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>,
# ...

# %%
eachTag = itemTag[0]

# %%
eachTag
# Out:
# <item><거래금액>    60,000</거래금액><거래유형> </거래유형><건축년도>1981</건축년도><년>2015</년><법정동> 당주동</법정동><아파트>롯데미도파광화문빌딩</아파트><월>12</월><일>22</일><전용면적>149.95</전용면적><중개사소재지> </중개사소재지><지번>145</지번><지역코드>11110</지역코드><층>8</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item>

# %%
columns = eachTag.findAll()

# %%
columns[0]
# Out:
# <거래금액>    82,500</거래금액>

# %%
columns[0].name
# Out:
# '거래금액'

# %%
columns[0].text
# Out:
# '    82,500'

# %%
rowList = []
columnList = []

# %%
columnList.append()

# %%
columnList.append()
rowList.append(columnList)
columnList=[]

# %%
for j in range(0, len(columns)):
    rowList = columns[j].findAll()
    for i in range(0, len(columns)):
        columnList.append(columns[i].name)
        columnList.append(columns[i].text)
        rowList.append(columnList)
        columnList = []

# %%
pd.DataFrame(rowList)
# Out:
#           0                    1
# 0      거래금액               82,500
# 1      거래유형
# 2      건축년도                 2008
# 3         년                 2015
# 4       법정동                  사직동
# 5       아파트  광화문스페이스본(101동~105동)
# 6         월                   12
# 7         일                   10
# 8      전용면적                94.51
# 9    중개사소재지
# 10       지번                    9
# 11     지역코드                11110
# 12        층                   11
# 13  해제사유발생일
# 14     해제여부
